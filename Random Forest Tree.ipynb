# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('whitegrid')
import statsmodels.api as sm

# %%
dataset = pd.read_csv('StudentsPerformance.csv')

# %%
dataset['average_score']=((dataset["math_score"]+dataset["reading_score"]+dataset["writing_score"])/3).round()
dataset['results'] = np.where(dataset['average_score']>= 50, '1', '0')
dataset.head()
# Out:
#    Unnamed: 0  gender race_ethnicity parental_level_of_education  \
# 0           1  female        group B           bachelor's degree
# 1           2  female        group C                some college
# 2           3  female        group B             master's degree
# 3           4    male        group A          associate's degree
# 4           5    male        group C                some college
#
#           lunch test_preparation_course  math_score  reading_score  \
# 0      standard                    none          72             72
# 1      standard               completed          69             90
# 2      standard                    none          90             95
# 3  free/reduced                    none          47             57
# 4      standard                    none          76             78
#
#    writing_score  average_score results
# 0             74           73.0       1
# 1             88           82.0       1
# 2             93           93.0       1
# 3             44           49.0       0
# 4             75           76.0       1

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder= LabelEncoder()
dataset['gender'] = label_encoder.fit_transform(dataset['gender'])
dataset['race_ethnicity'] = label_encoder.fit_transform(dataset['race_ethnicity'])
dataset['parental_level_of_education'] = label_encoder.fit_transform(dataset['parental_level_of_education'])
dataset['lunch'] = label_encoder.fit_transform(dataset['lunch'])
dataset['test_preparation_course'] = label_encoder.fit_transform(dataset['test_preparation_course'])

# %%
x = dataset.drop(['results'], axis=1)

y = dataset['results']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 0)

# %%
x_train.shape, x_test.shape
# Out:
# ((750, 10), (250, 10))

# %%
x_train.dtypes
# Out:
# Unnamed: 0                       int64
# gender                           int64
# race_ethnicity                   int64
# parental_level_of_education      int64
# lunch                            int64
# test_preparation_course          int64
# math_score                       int64
# reading_score                    int64
# writing_score                    int64
# average_score                  float64
# dtype: object

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(random_state=0)

# %%
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
y_pred = rfc.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print('Model accuracy score with 10 decision-trees : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score with 10 decision-trees : 1.0000

# %%
rfc_100 = RandomForestClassifier(n_estimators=100, random_state=0)

# %%
rfc_100.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
y_pred_100 = rfc_100.predict(x_test)

# %%
print('Model accuracy score with 100 decision-trees : {0:0.4f}'. format(accuracy_score(y_test, y_pred_100)))
# Out:
# Model accuracy score with 100 decision-trees : 1.0000

# %%
clf = RandomForestClassifier(n_estimators=100, random_state=0)

# %%
clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
feature_scores = pd.Series(clf.feature_importances_, index=x_train.columns).sort_values(ascending=False)

feature_scores
# Out:
# average_score                  0.552991
# writing_score                  0.213144
# reading_score                  0.147626
# math_score                     0.068858
# Unnamed: 0                     0.007521
# race_ethnicity                 0.002516
# gender                         0.002417
# lunch                          0.002079
# parental_level_of_education    0.001480
# test_preparation_course        0.001368
# dtype: float64

# %%
s = dataset.drop(['test_preparation_course', 'gender'], axis=1)

y = dataset['results']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 0)

# %%
clf = RandomForestClassifier(random_state=0)

# %%
clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
y_pred = clf.predict(x_test)

# %%
print('Model accuracy score with test preparation course variable removed : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score with test preparation course variable removed : 1.0000
